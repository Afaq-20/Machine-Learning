# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
plt.gray()
for i in range(9):
    plt.matshow(digits.images[i])

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data,digits.target,test_size = 0.2)

# %%
len(X_test)
# Out:
# 360

# %%
model = linear_model.LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([7, 4, 0, 1, 0, 1, 0, 8, 3, 1, 0, 2, 9, 3, 9, 4, 0, 9, 7, 0, 0, 7,
#        5, 3, 6, 7, 8, 4, 5, 4, 4, 6, 1, 5, 9, 6, 2, 2, 1, 4, 1, 4, 3, 7,
#        3, 1, 4, 4, 6, 8, 3, 9, 2, 2, 9, 0, 8, 5, 1, 8, 4, 8, 3, 4, 8, 0,
#        3, 9, 7, 4, 1, 8, 2, 1, 2, 9, 3, 3, 3, 4, 5, 4, 4, 4, 7, 2, 0, 6,
#        9, 3, 5, 5, 9, 4, 4, 8, 9, 6, 9, 3, 5, 6, 7, 7, 7, 4, 4, 5, 7, 8,
#        8, 5, 1, 9, 8, 0, 4, 3, 2, 7, 5, 5, 1, 9, 7, 4, 5, 1, 8, 6, 9, 5,
#        8, 0, 8, 5, 1, 1, 4, 8, 7, 3, 6, 8, 1, 9, 8, 0, 9, 2, 1, 7, 2, 7,
#        6, 0, 8, 3, 7, 0, 4, 1, 1, 9, 6, 1, 2, 7, 1, 1, 2, 2, 6, 3, 0, 7,
#        3, 3, 5, 0, 2, 0, 3, 8, 6, 6, 5, 4, 2, 4, 8, 8, 2, 8, 7, 7, 2, 0,
#        1, 7, 9, 3, 6, 2, 9, 3, 1, 8, 4, 0, 3, 5, 5, 7, 1, 0, 5, 5, 5, 6,
#        3, 9, 4, 2, 2, 1, 0, 6, 9, 9, 3, 3, 1, 9, 5, 0, 4, 0, 8, 1, 7, 5,
#        1, 0, 1, 6, 7, 2, 8, 5, 9, 3, 6, 5, 7, 0, 5, 1, 0, 0, 4, 9, 6, 1,
#        8, 3, 9, 2, 5, 4, 3, 5, 1, 1, 2, 8, 6, 1, 8, 9, 6, 1, 5, 0, 8, 5,
#        4, 6, 0, 8, 2, 9, 2, 7, 4, 8, 0, 4, 9, 0, 9, 3, 3, 5, 8, 0, 2, 9,
#        2, 3, 3, 8, 9, 4, 4, 7, 6, 0, 3, 1, 3, 1, 1, 9, 7, 9, 4, 6, 7, 9,
#        9, 9, 0, 3, 3, 9, 2, 2, 6, 1, 6, 8, 8, 5, 4, 1, 3, 6, 1, 3, 5, 2,
#        1, 3, 7, 5, 0, 2, 0, 4])

# %%
y_test
# Out:
# array([7, 4, 0, 1, 0, 1, 0, 8, 3, 1, 0, 2, 9, 3, 9, 4, 0, 9, 7, 0, 0, 7,
#        5, 3, 6, 7, 8, 4, 5, 4, 4, 6, 1, 5, 9, 6, 2, 2, 1, 4, 1, 4, 3, 7,
#        3, 1, 4, 4, 6, 8, 3, 9, 2, 2, 9, 0, 8, 5, 1, 9, 4, 8, 3, 4, 6, 0,
#        3, 9, 7, 4, 1, 8, 2, 1, 2, 9, 3, 3, 3, 4, 5, 4, 4, 4, 7, 2, 0, 6,
#        9, 3, 5, 5, 9, 1, 4, 8, 9, 6, 9, 3, 5, 6, 7, 7, 7, 4, 4, 5, 7, 8,
#        8, 5, 1, 9, 8, 0, 4, 3, 2, 7, 5, 5, 1, 9, 7, 4, 5, 1, 6, 6, 9, 5,
#        8, 0, 8, 5, 1, 1, 4, 8, 7, 3, 6, 8, 1, 9, 8, 0, 9, 2, 1, 7, 2, 7,
#        6, 0, 8, 3, 7, 0, 4, 1, 1, 9, 6, 1, 2, 7, 1, 1, 2, 2, 6, 3, 0, 3,
#        3, 8, 5, 0, 2, 0, 3, 8, 6, 6, 9, 4, 2, 4, 8, 8, 2, 1, 7, 7, 2, 0,
#        1, 7, 9, 3, 6, 2, 5, 3, 1, 8, 4, 0, 3, 5, 5, 7, 8, 0, 5, 5, 5, 6,
#        3, 9, 4, 2, 2, 1, 0, 6, 9, 9, 3, 3, 1, 9, 5, 0, 4, 0, 8, 1, 7, 5,
#        1, 0, 1, 6, 7, 2, 8, 5, 9, 3, 6, 5, 7, 0, 5, 1, 0, 0, 4, 9, 6, 1,
#        1, 3, 9, 2, 5, 4, 3, 5, 1, 1, 2, 8, 6, 1, 8, 9, 6, 8, 5, 0, 8, 5,
#        4, 6, 0, 8, 2, 9, 2, 7, 4, 8, 0, 4, 9, 0, 9, 3, 3, 5, 8, 0, 2, 9,
#        2, 3, 3, 8, 9, 4, 4, 7, 6, 9, 3, 1, 3, 8, 1, 9, 7, 9, 7, 6, 7, 9,
#        9, 9, 0, 3, 3, 9, 2, 2, 6, 1, 6, 8, 8, 5, 4, 1, 3, 6, 1, 3, 5, 2,
#        1, 3, 7, 5, 0, 2, 0, 4])

# %%
model.score(X_test,y_test)
# Out:
# 0.9583333333333334

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,y_predicted)

# %%
import seaborn as sns
plt.figure(figsize = (11,7))
sns.heatmap(cm,annot =True)
# Out:
# <Axes: >

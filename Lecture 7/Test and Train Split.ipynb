# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('carprices.csv')

# %%
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
sns.pairplot(df, x_vars=['Mileage','Age(yrs)'], y_vars=['Sell Price($)'])
plt.show()

# %%
x = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,  y_test = train_test_split(x,y,test_size = .2)

# %%
af = linear_model.LinearRegression()

# %%
af.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
af.predict([[69000,8]])
# Out:
# array([21324.92315918])

# %%
af.score(x_test,y_test)
# Out:
# 0.9215198615455589

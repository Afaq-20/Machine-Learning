# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('test_scores.csv')

# %%
df.head(5)
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83

# %%
x = np.array(df.math)
y = np.array(df.cs)

# %%
def gradDescent(x,y):
    m = b = 0
    rate = 0.00001
    n = len(x)
    for i in range(999):

        ypredict = m * x + b
        plt.plot(x,ypredict,color = 'red')


        costfx = (1/n)* sum(y-ypredict)
        
        md = -(2/n) * sum(x * (y-ypredict))
        bd = -(2/n) * sum((y-ypredict))

        m = m - rate * md
        b = b - rate * bd

# %%
gradDescent(x,y)
